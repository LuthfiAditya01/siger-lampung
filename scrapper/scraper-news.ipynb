# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta
import time
import os
import json
import re

# %%
key="megalodon"
keyword = "+".join(key.split())
print(keyword)
max_pages=10
retries=3
timeout=50
# Out:
# megalodon

# %% [markdown]
# # ANTARANEWS

# %%
def get_search_results_antaranews(keyword, max_pages, retries, timeout):
    base_url = f"https://lampung.antaranews.com/search?q={keyword}&page="
    links = []
    page = 1
    
    # List penampung data
    tanggal_list = []
    nama_media_list = []
    judul_list = []
    link_list = []

    for page in range(1, max_pages + 1):
        url = base_url + str(page)
        for attempt in range(retries):
            try:
                response = requests.get(url, timeout)
                response.raise_for_status()
                break
            except (requests.ConnectionError, requests.Timeout) as e:
                print(f"Attempt {attempt+1} failed: {e}")
                if attempt < retries - 1:
                    time.sleep(2 ** attempt)
                else:
                    print(f"Failed to retrieve page {page}. Skipping.")
                    return links
            except requests.RequestException as e:
                print(f"Request failed: {e}")
                return links

        soup = BeautifulSoup(response.content, 'html.parser')
        col_md8 = soup.find('div', class_='col-md-8')

        if col_md8:
            h3_tags = col_md8.find_all('h3', limit=10)
            for h3 in h3_tags:
                link = h3.find('a', href=True)
                if link and 'berita' in link['href']:
                    links.append(link['href'])
                    tautan = link['href']
                    judul = link['title']
            p_tags = col_md8.find_all('p', limit=10)
            for p in p_tags:
                span = p.find('span')
                if span:
                    tanggal_text = span.get_text(strip=True)
                    if "jam" in tanggal_text.lower():
                        # Kalau ada kata "jam", langsung set kemarin
                        tanggal_format = (datetime.today() - timedelta(days=1)).strftime("%Y-%m-%d")
                    else:
                        tanggal_text_clean = re.sub(r'Wib.*', '', tanggal_text, flags=re.IGNORECASE).strip()
                        dt = datetime.strptime(tanggal_text_clean, "%d %B %Y %H:%M")
                        tanggal_format = dt.strftime("%Y-%m-%d")
                    
        nama_media = "Antara News"
        # Append ke list
        tanggal_list.append(tanggal_format)
        nama_media_list.append(nama_media)
        judul_list.append(judul)
        link_list.append(tautan)

        # Memeriksa apakah ada halaman berikutnya untuk diakses lagi
        pagination = soup.find('ul', class_='pagination pagination-sm')
        if pagination:
            next_page = None
            for a_tag in pagination.find_all('a'):
                if a_tag.get('aria-label') == 'Next':
                    next_page = a_tag.get('href')
                    break
            if next_page:
                page=page+1
            else:
                break
        else:
            break
    # Buat DataFrame
    data = {
        'Tanggal': tanggal_list,
        'Nama Media': nama_media_list,
        'Judul': judul_list,
        'Link': link_list
    }
    df = pd.DataFrame(data, columns=['Tanggal', 'Nama Media', 'Judul', 'Link'])

    return df

# %%
df_antaranews = get_search_results_antaranews(keyword, max_pages, retries, timeout)
df_antaranews
# Out:
# https://lampung.antaranews.com/search?q=megalodon&page=1
# Request failed: 404 Client Error: Not Found for url: https://lampung.antaranews.com/search?q=megalodon&page=1&50
# []

# %% [markdown]
# # VIVA LAMPUNG

# %%
def get_search_results_viva(keyword, max_pages, retries, timeout):
    base_url = "https://lampung.viva.co.id/search?q={keyword}"
    page = 1
    links = []

    bulan_map = {
                "Januari": "01", "Februari": "02", "Maret": "03", "April": "04",
                "Mei": "05", "Juni": "06", "Juli": "07", "Agustus": "08",
                "September": "09", "Oktober": "10", "November": "11", "Desember": "12"
    }
    
    # List penampung data
    tanggal_list = []
    nama_media_list = []
    judul_list = []
    link_list = []

    url = base_url.format(keyword=keyword, page=page)
    
    for attempt in range(retries):
        try:
            response = requests.get(url, timeout)
            response.raise_for_status()
            break
        except (requests.ConnectionError, requests.Timeout) as e:
            # print(f"Attempt {attempt + 1} failed: {e}")
            if attempt < retries - 1:
                time.sleep(2 ** attempt)
            else:
                # print(f"Failed to retrieve page {page}. Skipping.")
                return links
        except requests.RequestException as e:
            # print(f"Request failed: {e}")
            return links

    soup = BeautifulSoup(response.text, 'html.parser')

    # Cari container besar
    container = soup.find("div", class_="column-big-container")

    for article in container.find_all("div", class_="article-list-row"):
        info = article.find("div", class_="article-list-info content_center")

        # Ambil href di <a>
        a_tag = info.find("a")
        href = a_tag.get("href") if a_tag else None

        # Ambil judul di <h2>
        h2_tag = info.find("h2")
        judul = h2_tag.get_text(strip=True) if h2_tag else None

        # Ambil tanggal
        date_div = info.find("div", class_="article-list-date content_center")
        tanggal_text = date_div.get_text(strip=True) if date_div else None
        if tanggal_text:
            tanggal_only = tanggal_text.split("|")[0].strip()
            tgl_parts = tanggal_only.split()
            if len(tgl_parts) == 3:
                day = tgl_parts[0]
                month = bulan_map.get(tgl_parts[1], "01")
                year = tgl_parts[2]
                tanggal_format = f"{year}-{month}-{day}"
            else:
                tanggal_format = None
        else:
            tanggal_format = None

        nama_media = "Viva Lampung"
        # Append ke list
        tanggal_list.append(tanggal_format)
        nama_media_list.append(nama_media)
        judul_list.append(judul)
        link_list.append(href)
            
    # Buat DataFrame
    data = {
        'Tanggal': tanggal_list,
        'Nama Media': nama_media_list,
        'Judul': judul_list,
        'Link': link_list
    }
    df = pd.DataFrame(data, columns=['Tanggal', 'Nama Media', 'Judul', 'Link'])

    return df

# %%
df_viva = get_search_results_viva(keyword, max_pages, retries, timeout)
df_viva
# Out:
#       Tanggal    Nama Media  \
# 0  2025-05-12  Viva Lampung
#
#                                                Judul  \
# 0  Sekolah Rakyat Siap Hadir di Lampung, Gus Ipul...
#
#                                                 Link
# 0  https://lampung.viva.co.id/berita/5493-sekolah...

# %% [markdown]
# # LAMPUNG POST

# %%
def get_search_results_lampungpost(keyword, max_pages, timeout):
    base_url = f"https://lampost.co/page/{{}}/?s={keyword}"
    
    # List penampung data
    tanggal_list = []
    nama_media_list = []
    judul_list = []
    link_list = []
    
    for page in range(1, max_pages + 1):
        url = base_url.format(page)
        response = requests.get(url, timeout)
        soup = BeautifulSoup(response.content, 'html.parser')

        articles = soup.find_all("article", class_="jeg_post")

        for art in articles:
            # Ambil link & judul
            title_tag = art.find("h3", class_="jeg_post_title").find("a")
            judul = title_tag.get_text(strip=True)
            link = title_tag["href"]

            # Ambil tanggal
            date_tag = art.find("div", class_="jeg_meta_date").find("a")
            tanggal_raw = date_tag.get_text(strip=True) 
            tanggal_format = datetime.strptime(tanggal_raw, "%d/%m/%Y").strftime("%Y-%m-%d")

            nama_media = "Lampung Post"
            # Append ke list
            tanggal_list.append(tanggal_format)
            nama_media_list.append(nama_media)
            judul_list.append(judul)
            link_list.append(link)
        
        pagination_div = soup.find("div", class_="jeg_navigation")
        if pagination_div:
            page += 1
        else:
            break
    
    # Buat DataFrame
    data = {
        'Tanggal': tanggal_list,
        'Nama Media': nama_media_list,
        'Judul': judul_list,
        'Link': link_list
    }
    df = pd.DataFrame(data, columns=['Tanggal', 'Nama Media', 'Judul', 'Link'])

    return df

# %%
df_lampungpost = get_search_results_lampungpost(keyword, max_pages, timeout)
df_lampungpost
# Out:
#         Tanggal    Nama Media  \
# 0    2025-08-12  Lampung Post
# 1    2025-08-11  Lampung Post
# 2    2025-08-11  Lampung Post
# 3    2025-08-03  Lampung Post
# 4    2025-07-15  Lampung Post
# ..          ...           ...
# 116  2025-08-13  Lampung Post
# 117  2025-08-13  Lampung Post
# 118  2025-08-13  Lampung Post
# 119  2025-08-13  Lampung Post
# 120  2025-08-13  Lampung Post
#
#                                                  Judul  \
# 0    Kegiatan di Sekolah Rakyat Tertunda, Siswa Mer...
# 1    Sekolah Rakyat Mulai Berlangsung pada 15 Agust...
# 2    Bangunan Belum Rampung, Proses Pembelajaran Se...
# 3    Renovasi Belum Selesai, Pembelajaran Sekolah R...
# 4    MPLS Sekolah Rakyat Fokus Cek Kesehatan dan Te...
# ..                                                 ...
# 116  Bupati dan Wabup Lampung Tengah Hadiri Festiva...
# 117  Program MBG Buat Siswa Lebih Hemat dan Semanga...
# 118  Pemprov Lampung Siapkan Pembangunan SPPG di Se...
# 119  Klub Asal Italia Como Resmi Datangkan Alvaro M...
# 120     Polres Lampung Timur Tangkap Tiga Pelaku Curas
#
#                                                   Link
# 0    https://lampost.co/humaniora/kegiatan-di-sekol...
# 1    https://lampost.co/humaniora/sekolah-rakyat-mu...
# 2    https://lampost.co/lampung/bangunan-belum-ramp...
# 3    https://lampost.co/humaniora/pembelajaran-dari...
# 4    https://lampost.co/lampung/mpls-sekolah-rakyat...
# ..                                                 ...
# 116  https://lampost.co/lampung/lampung-tengah/bupa...
# 117  https://lampost.co/humaniora/program-mbg-buat-...
# 118  https://lampost.co/humaniora/pemprov-lampung-s...
# 119  https://lampost.co/olahraga/klub-asal-italia-c...
# 120  https://lampost.co/kriminal/polres-lampung-tim...
#
# [121 rows x 4 columns]

# %% [markdown]
# # SINAR LAMPUNG

# %%
def get_search_results_sinarlampung(keyword, max_pages, timeout):
    base_url = f"https://sinarlampung.co/search/?q={keyword}&page="
    page = 1

    # List penampung data
    tanggal_list = []
    nama_media_list = []
    judul_list = []
    link_list = []

    while page <= max_pages:
        url = base_url + str(page)
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36"
        }
        response = requests.get(url, headers=headers, timeout=timeout)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            articles = soup.find_all("article", class_="flex flex-col md:flex-row gap-4 bg-[#1e293b] rounded-lg overflow-hidden hover:bg-[#1e293b]/80 transition-colors duration-300 shadow-md group")

            for art in articles:
                # href
                link_tag = art.find("a", class_="block h-full")
                href = "https://sinarlampung.co" + link_tag["href"] if link_tag else None

                # alt
                img_tag = art.find("img")
                alt = img_tag["alt"] if img_tag else None

                # datetime -> YYYY-MM-DD
                time_tag = art.find("time")
                date_str = None
                if time_tag and time_tag.has_attr("datetime"):
                    date_str = time_tag["datetime"].split("T")[0]
                
                nama_media = "Sinar Lampung"
                # Append ke list
                tanggal_list.append(date_str)
                nama_media_list.append(nama_media)
                judul_list.append(alt)
                link_list.append(href)
                
            # Deteksi pagination
            has_pagination = soup.find("div", class_="flex justify-center mt-8") is not None

            if has_pagination:
                page=page+1
            else:
                break
        else:
            break
    # Buat DataFrame
    data = {
        'Tanggal': tanggal_list,
        'Nama Media': nama_media_list,
        'Judul': judul_list,
        'Link': link_list
    }
    df = pd.DataFrame(data, columns=['Tanggal', 'Nama Media', 'Judul', 'Link'])

    return df

# %%
df_sinarlampung = get_search_results_sinarlampung(keyword, max_pages, timeout)
df_sinarlampung
# Out:
#        Tanggal     Nama Media  \
# 0   2025-08-10  Sinar Lampung
# 1   2025-08-04  Sinar Lampung
# 2   2025-08-03  Sinar Lampung
# 3   2025-07-27  Sinar Lampung
# 4   2025-07-25  Sinar Lampung
# ..         ...            ...
# 95  2021-06-25  Sinar Lampung
# 96  2021-06-17  Sinar Lampung
# 97  2021-06-11  Sinar Lampung
# 98  2021-05-10  Sinar Lampung
# 99  2021-05-05  Sinar Lampung
#
#                                                 Judul  \
# 0   Ketua LMPI Tanggamus “Kalau Guru Sudah Lupa Ma...
# 1   Dugaan Korupsi Pengadaan Buku dan Bunda Litera...
# 2   Bob Hasan Dorong Kesejahteraan Petani Singkong...
# 3   BPS Catat Sekitar 52 Ribu Penduduk Lampung Tak...
# 4   Sidang Ijazah Palsu Anggota DPRD PDIP Lampung ...
# ..                                                ...
# 95  Waktu Penerimaan Peserta Didik Baru SMAN di Ba...
# 96  Gunakan Ijazah Palsu, Dewan PPP Lampung Barat ...
# 97  Pengumuman Pemenang Lomba Menulis Cerpen Mobil...
# 98  Amankan Pelajar Berdua di Lapangan Lalu Dibawa...
# 99  Diduga Pungli, K3S Pesisir Barat Minta Iuran K...
#
#                                                  Link
# 0   https://sinarlampung.co/2025/08/10/ketua-lmpi-...
# 1   https://sinarlampung.co/2025/08/04/dugaan-koru...
# 2   https://sinarlampung.co/2025/08/03/bob-hasan-d...
# 3   https://sinarlampung.co/2025/07/27/bps-catat-s...
# 4   https://sinarlampung.co/2025/07/25/sidang-ijaz...
# ..                                                ...
# 95  https://sinarlampung.co/2021/06/25/waktu-pener...
# 96  https://sinarlampung.co/2021/06/17/gunakan-ija...
# 97  https://sinarlampung.co/2021/06/11/pengumuman-...
# 98  https://sinarlampung.co/2021/05/10/amankan-pel...
# 99  https://sinarlampung.co/2021/05/05/diduga-pung...
#
# [100 rows x 4 columns]

# %% [markdown]
# # DETIK SUMBAGSEL

# %%
def get_search_results_detiksumbagsel(keyword, max_pages, timeout):
    page = 1
    bulan_map = {
                "Janu": "01", "Feb": "02", "Mar": "03", "Apr": "04",
                "Mei": "05", "Jun": "06", "Jul": "07", "Agu": "08",
                "Sep": "09", "Okt": "10", "Nov": "11", "Des": "12"
    }
    # List penampung data
    tanggal_list = []
    nama_media_list = []
    judul_list = []
    link_list = []
    
    while page <= max_pages:
        url = f"https://www.detik.com/search/searchall?query={keyword}&page={page}&result_type=relevansi&siteid=154"
        response = requests.get(url, timeout)

        
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')

            for article in soup.select("article.list-content__item"):
                # Judul & Link
                a_tag = article.select_one("h3.media__title a")
                dtr_ttl = a_tag.get("dtr-ttl", "").strip()
                href = a_tag.get("href", "").strip()

                # Nama media (misal di h2.media__subtitle)
                nama_media_tag = article.select_one("h2.media__subtitle")
                nama_media = nama_media_tag.get_text(strip=True) if nama_media_tag else ""

                # Tanggal
                span_tag = article.select_one(".media__date span")
                title_date = span_tag.get("title", "").strip()

                # Parsing tanggal ke YYYY-MM-DD
                parts = title_date.split()
                day = parts[1]
                month = bulan_map.get(parts[2], "01")
                year = parts[3]
                tanggal_format = f"{year}-{month}-{day}"

                # Append ke list
                tanggal_list.append(tanggal_format)
                nama_media_list.append(nama_media)
                judul_list.append(dtr_ttl)
                link_list.append(href)

            # Pengecekan apakah ada halaman selanjutnya
            pagination = soup.find("div", class_="pagination")
            if pagination:
                # Ambil semua link yang punya angka (bukan "Prev" / "Next")
                page_numbers = []
                for a in pagination.find_all("a", class_="itp-pagination"):
                    try:
                        page_numbers.append(int(a.get_text(strip=True)))
                    except ValueError:
                        pass  # kalau bukan angka, skip

                if page_numbers:
                    last_page = max(page_numbers)  # halaman terakhir
                    if page < last_page:
                        page += 1
                    else:
                        break
                else:
                    break
            else:
                break
        else:
            print(f"Error fetching page {page}: {response.status_code}")
            break

    # Buat DataFrame
    data = {
        'Tanggal': tanggal_list,
        'Nama Media': nama_media_list,
        'Judul': judul_list,
        'Link': link_list
    }
    df = pd.DataFrame(data, columns=['Tanggal', 'Nama Media', 'Judul', 'Link'])

    return df

# %%
df_detiksumbagsel = get_search_results_detiksumbagsel(keyword,max_pages, timeout)
df_detiksumbagsel
# Out:
#         Tanggal      Nama Media  \
# 0    2025-06-28  detikSumbagsel
# 1    2025-06-27  detikSumbagsel
# 2    2025-06-19  detikSumbagsel
# 3    2025-08-04         20Detik
# 4    2025-06-18  detikSumbagsel
# ..          ...             ...
# 101  2025-03-06  detikSumbagsel
# 102  2025-03-06  detikSumbagsel
# 103  2024-11-21  detikSumbagsel
# 104  2024-11-21  detikSumbagsel
# 105  2024-11-11  detikSumbagsel
#
#                                                  Judul  \
# 0    Pemerintah Sebut 200 Sekolah Rakyat Dibuka Tah...
# 1    Renovasi Sekolah Rakyat Palembang Ditarget Kel...
# 2    BBS Tegaskan Pentingnya Kehadiran Sekolah Raky...
# 3    Video Kemenkes: 46% Siswa Sekolah Rakyat Punya...
# 4    Wakil KSP Sebut Sekolah Rakyat di Jambi Dibuka...
# ..                                                 ...
# 101  Ratu Dewa Prihatin Banyak Sekolah di Palembang...
# 102  Zulfakrianto Spesialis Bobol Toko Ditangkap Us...
# 103  Paslon Eddy-Riezky Janji Hilangkan Pungli di S...
# 104  Terduga Teroris di OKU Timur Ditangkap Usai An...
# 105  Heboh Siswa SMP Mirip Wapres Gibran, Sekolah I...
#
#                                                   Link
# 0    https://www.detik.com/sumbagsel/berita/d-79856...
# 1    https://www.detik.com/sumbagsel/berita/d-79835...
# 2    https://www.detik.com/sumbagsel/berita/d-79713...
# 3    https://20.detik.com/detikupdate/20250804-2508...
# 4    https://www.detik.com/sumbagsel/berita/d-79693...
# ..                                                 ...
# 101  https://www.detik.com/sumbagsel/hukum-dan-krim...
# 102  https://www.detik.com/sumbagsel/hukum-dan-krim...
# 103  https://www.detik.com/sumbagsel/pilkada/d-7650...
# 104  https://www.detik.com/sumbagsel/hukum-dan-krim...
# 105  https://www.detik.com/sumbagsel/berita/d-76326...
#
# [106 rows x 4 columns]

# %% [markdown]
# # HARIAN LAMPUNG

# %%
def get_search_results_harianlampung(keyword, timeout):
    base_url = f"https://harianlampung.id/?s={keyword}&post_type%5B%5D=post"

    # List penampung data
    tanggal_list = []
    nama_media_list = []
    judul_list = []
    link_list = []

    url = base_url
    response = requests.get(url, timeout)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        articles = soup.find_all("article", class_="post")

        for art in articles:
            # Judul & Link
            title_tag = art.find("h2", class_="entry-title").a
            title = title_tag.get_text(strip=True)
            link = title_tag["href"]

            # Tanggal
            time_tag = art.find("time", class_="published")
            date_str = time_tag["datetime"] if time_tag else None
            date_formatted = datetime.fromisoformat(date_str.replace("Z", "+00:00")).strftime("%Y-%m-%d") if date_str else None

            nama_media = "Harian Lampung"
            # Append ke list
            tanggal_list.append(date_formatted)
            nama_media_list.append(nama_media)
            judul_list.append(title)
            link_list.append(link)
            
    # Buat DataFrame
    data = {
        'Tanggal': tanggal_list,
        'Nama Media': nama_media_list,
        'Judul': judul_list,
        'Link': link_list
    }
    df = pd.DataFrame(data, columns=['Tanggal', 'Nama Media', 'Judul', 'Link'])

    return df

# %%
df_harianlampung = get_search_results_harianlampung(keyword, timeout)
df_harianlampung
# Out:
#       Tanggal      Nama Media  \
# 0  2025-07-26  Harian Lampung
# 1  2025-04-14  Harian Lampung
# 2  2024-06-13  Harian Lampung
# 3  2024-06-03  Harian Lampung
# 4  2024-05-29  Harian Lampung
#
#                                                Judul  \
# 0  Infrastruktur Waykanan Semakin Hancur dan Dise...
# 1  DPRD Kota Metro Kembali Gelar Rapat Paripurna,...
# 2  Terkait Mutasi Guru Tidak Sesuai Mekanisme, Ko...
# 3  Mutasi Guru yang Tidak Sesuai Mekanisme, Komis...
# 4  Bupati Lamsel Harus Evaluasi Pejabat Dinas Pen...
#
#                                                 Link
# 0  https://harianlampung.id/infrastruktur-waykana...
# 1  https://harianlampung.id/dprd-kota-metro-kemba...
# 2  https://harianlampung.id/terkait-mutasi-guru-t...
# 3  https://harianlampung.id/mutasi-guru-yang-tida...
# 4  https://harianlampung.id/bupati-lamsel-harus-e...

# %% [markdown]
# # HARIAN FAJAR LAMPUNG

# %%
def get_search_results_harianfajarlampung(keyword, timeout):
    base_url = f"https://harianfajarlampung.co.id/?s={keyword}&post_type=post"

    # List penampung data
    tanggal_list = []
    nama_media_list = []
    judul_list = []
    link_list = []

    url = base_url
    response = requests.get(url, timeout)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')

        for article in soup.find_all("article"):
            # tanggal
            tanggal_raw = article.select_one("time")["datetime"]  # ambil datetime dari atribut
            tanggal = datetime.fromisoformat(tanggal_raw.replace("Z", "+00:00")).strftime("%Y-%m-%d")

            # judul & link
            judul_tag = article.select_one("h2.entry-title a")
            judul = judul_tag.get_text(strip=True)
            link = judul_tag["href"]

            nama_media = "Harian Fajar Lampung"
            # Append ke list
            tanggal_list.append(tanggal)
            nama_media_list.append(nama_media)
            judul_list.append(judul)
            link_list.append(link)

    # Buat DataFrame
    data = {
        'Tanggal': tanggal_list,
        'Nama Media': nama_media_list,
        'Judul': judul_list,
        'Link': link_list
    }
    df = pd.DataFrame(data, columns=['Tanggal', 'Nama Media', 'Judul', 'Link'])

    return df

# %%
df_harianfajarlampung = get_search_results_harianfajarlampung(keyword, timeout)
df_harianfajarlampung
# Out:
# Empty DataFrame
# Columns: [Tanggal, Nama Media, Judul, Link]
# Index: []

# %% [markdown]
# # SERAMBI LAMPUNG

# %%
def get_search_results_serambilampung(keyword, max_pages, timeout):
    page = 1

    # List penampung data
    tanggal_list = []
    nama_media_list = []
    judul_list = []
    link_list = []

    bulan_map = {
    "Januari": "01", "Februari": "02", "Maret": "03", "April": "04",
    "Mei": "05", "Juni": "06", "Juli": "07", "Agustus": "08",
    "September": "09", "Oktober": "10", "November": "11", "Desember": "12"
    }

    while page <= max_pages:
        url = f"https://serambilampung.com/page/{page}/?s={keyword}"
        response = requests.get(url, timeout)

        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            articles = soup.find_all("div", class_="category-text-wrap")

            for art in articles:
                a_tag = art.find("h2").find("a")
                title = a_tag.get_text(strip=True)
                link = a_tag["href"]

                # Ambil teks tanggal mentah
                span_tag = art.find("p", class_="category-kategori").find("span")
                raw_date = span_tag.get_text(strip=True)  # "Senin, 11 Agustus 2025  - 17:00 WIB"
                
                # Ambil bagian tanggal saja
                date_part = raw_date.split("-")[0].strip()  # "Senin, 11 Agustus 2025"
                date_only = date_part.split(", ")[-1]       # "11 Agustus 2025"
                
                # Pecah tanggal
                day, month_name, year = date_only.split(" ")
                month_num = bulan_map[month_name]
                
                date_str = f"{year}-{month_num}-{day.zfill(2)}"
                
                nama_media = "Serambi Lampung"
                # Append ke list
                tanggal_list.append(date_str)
                nama_media_list.append(nama_media)
                judul_list.append(title)
                link_list.append(link)
                        
            # Deteksi pagination
            has_pagination = soup.find("div", class_="navigation") is not None

            if has_pagination:
                page=page+1
            else:
                break
        else:
            break
        
    # Buat DataFrame
    data = {
        'Tanggal': tanggal_list,
        'Nama Media': nama_media_list,
        'Judul': judul_list,
        'Link': link_list
    }
    df = pd.DataFrame(data, columns=['Tanggal', 'Nama Media', 'Judul', 'Link'])

    return df

# %%
df_serambilampung = get_search_results_serambilampung(keyword, max_pages, timeout)
df_serambilampung
# Out:
#       Tanggal       Nama Media  \
# 0  2025-06-13  Serambi Lampung
# 1  2025-04-21  Serambi Lampung
# 2  2025-06-26  Serambi Lampung
# 3  2025-06-17  Serambi Lampung
# 4  2025-04-20  Serambi Lampung
# 5  2025-03-11  Serambi Lampung
# 6  2025-03-03  Serambi Lampung
#
#                                                Judul  \
# 0  Badan Anggaran DPRD Lamsel Soroti Penambahan A...
# 1  Kota Metro Tuan Rumah Rapat Kerja Wilayah II A...
# 2  Bupati Pesibar Lantik 413 CPNS, Tekankan Penga...
# 3  Fraksi Demokrat Desak Pendidikan SD-SMP Gratis...
# 4  Bersama dengan warga, Wali Kota dan Wakil Wali...
# 5  Drs. H. Ali Rahman, S.T., M.T. Berpulang: Way ...
# 6  Dihadapan Dewan, Hamartoni-Romli Paparkan Visi...
#
#                                                 Link
# 0  https://serambilampung.com/2025/06/badan-angga...
# 1  https://serambilampung.com/2025/04/kota-metro-...
# 2  https://serambilampung.com/2025/06/bupati-pesi...
# 3  https://serambilampung.com/2025/06/fraksi-demo...
# 4  https://serambilampung.com/2025/04/bersama-den...
# 5  https://serambilampung.com/2025/03/drs-h-ali-r...
# 6  https://serambilampung.com/2025/03/dihadapan-d...

# %% [markdown]
# # GEMA MEDIA

# %%
def get_search_results_gemamedia(keyword, max_pages, timeout):
    page = 1

    # List penampung data
    tanggal_list = []
    nama_media_list = []
    judul_list = []
    link_list = []

    bulan_map = {
    "Januari": "01", "Februari": "02", "Maret": "03", "April": "04",
    "Mei": "05", "Juni": "06", "Juli": "07", "Agustus": "08",
    "September": "09", "Oktober": "10", "November": "11", "Desember": "12"
    }

    while page <= max_pages:
        url = f"https://gemamedia.co/page/{page}/?s={keyword}"
        response = requests.get(url, timeout)

        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            articles = soup.find_all("article", class_="d-md-flex mg-posts-sec-post")

            for art in articles:
                # Link (ambil dari a.link-div kalau ada, kalau tidak dari h4 a)
                link_tag = art.select_one("a.link-div") or art.select_one("h4.entry-title a")
                link = link_tag.get("href") if link_tag else None
                
                # Judul
                title_tag = art.select_one("h4.entry-title a")
                title = title_tag.get_text(strip=True) if title_tag else None
                
                # Tanggal (format YYYY-MM-DD)
                date_tag = art.select_one("span.mg-blog-date a")
                if date_tag:
                    tanggal_raw = date_tag.get_text(strip=True).replace(",", "")
                    parts = tanggal_raw.split()
                    bulan = bulan_map.get(parts[0], "01")
                    hari = parts[1].zfill(2)
                    tahun = parts[2]
                    tanggal_format = f"{tahun}-{bulan}-{hari}"
                else:
                    tanggal_format = None
                
                nama_media = "Gema Media"
                # Append ke list
                tanggal_list.append(tanggal_format)
                nama_media_list.append(nama_media)
                judul_list.append(title)
                link_list.append(link)
                        
            # Deteksi pagination
            has_pagination = soup.find("div", class_="navigation") is not None

            if has_pagination:
                page=page+1
            else:
                break
        else:
            break
    # Buat DataFrame
    data = {
        'Tanggal': tanggal_list,
        'Nama Media': nama_media_list,
        'Judul': judul_list,
        'Link': link_list
    }
    df = pd.DataFrame(data, columns=['Tanggal', 'Nama Media', 'Judul', 'Link'])

    return df

# %%
df_gemamedia = get_search_results_gemamedia(keyword, max_pages, timeout)
df_gemamedia
# Out:
#        Tanggal  Nama Media                                              Judul  \
# 0   2025-05-13  Gema Media  Kunjungan Rumah Calon Siswa, Pemerintah Pastik...
# 1   2025-05-12  Gema Media  Jihan Dampingi Menteri Sosial Kunjungi Rencana...
# 2   2025-05-05  Gema Media  Gubernur Lampung Dukung Penuh Program Sekolah ...
# 3   2025-04-25  Gema Media  Pemprov Lampung Siapkan Kota Baru sebagai Loka...
# 4   2025-04-22  Gema Media  Gubernur Lampung Dorong Pendirian  Sekolah Rak...
# 5   2024-12-25  Gema Media      PKS Lampung Gelar Sekolah Kepemimpinan Partai
# 6   2023-12-20  Gema Media  Dharma Setyawan Terima Anugrah Revolusi Mental...
# 7   2023-12-08  Gema Media  Korem 043/Gatam Kembali Gelar “Dapur Masuk Sek...
# 8   2023-09-22  Gema Media  Korem 043/Gatam Launching Program Unggulan Kod...
# 9   2023-03-09  Gema Media  Ibu Iriana dan Anggota OASE KIM Bermain Permai...
# 10  2021-05-25  Gema Media  Bupati Pesisir Barat Monitoring Pelaksanaan Uj...
# 11  2020-11-04  Gema Media  Rahmad Darmawan Siap Ikut Membangun Sekolah Se...
#
#                                                  Link
# 0   https://gemamedia.co/2025/05/kunjungan-rumah-c...
# 1   https://gemamedia.co/2025/05/jihan-dampingi-me...
# 2   https://gemamedia.co/2025/05/gubernur-lampung-...
# 3   https://gemamedia.co/2025/04/pemprov-lampung-s...
# 4   https://gemamedia.co/2025/04/gubernur-lampung-...
# 5   https://gemamedia.co/2024/12/pks-lampung-gelar...
# 6   https://gemamedia.co/2023/12/dharma-setyawan-t...
# 7   https://gemamedia.co/2023/12/korem-043-gatam-k...
# 8   https://gemamedia.co/2023/09/korem-043-gatam-l...
# 9   https://gemamedia.co/2023/03/ibu-iriana-dan-an...
# 10  https://gemamedia.co/2021/05/bupati-pesisir-ba...
# 11  https://gemamedia.co/2020/11/rahmad-darmawan-s...

# %% [markdown]
# # INFO LAMPUNG

# %%
def get_search_results_infolampung(keyword, max_pages, timeout):
    page = 1

    # List penampung data
    tanggal_list = []
    nama_media_list = []
    judul_list = []
    link_list = []

    while page <= max_pages:
        url = f"https://www.infolampung.id/page/{page}/?s={keyword}"
        response = requests.get(url, timeout)

        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            items = soup.select("div.category-text-wrap")

            for item in items:
                # Judul & Link
                a_tag = item.select_one("h2 a")
                judul = a_tag.get_text(strip=True) if a_tag else None
                link = a_tag["href"] if a_tag else None

                # Tanggal
                tgl_tag = item.select_one("div.tanggal-mobile")
                if tgl_tag:
                    tgl_raw = tgl_tag.get_text(strip=True)
                    tgl_parts = tgl_raw.split("-")[0].strip()  # "Wednesday, 16 July 2025"
                    tgl_parts = " ".join(tgl_parts.split()[1:])  # buang hari → "16 July 2025"
                    tgl_obj = datetime.strptime(tgl_parts, "%d %B %Y")
                    tgl_format = tgl_obj.strftime("%Y-%m-%d")
                else:
                    tgl_format = None
                
                nama_media = "Info Lampung"
                # Append ke list
                tanggal_list.append(tgl_format)
                nama_media_list.append(nama_media)
                judul_list.append(judul)
                link_list.append(link)
                        
            # Deteksi pagination
            has_pagination = soup.find("div", class_="navigation") is not None

            if has_pagination:
                page=page+1
            else:
                break
        else:
            break
    # Buat DataFrame
    data = {
        'Tanggal': tanggal_list,
        'Nama Media': nama_media_list,
        'Judul': judul_list,
        'Link': link_list
    }
    df = pd.DataFrame(data, columns=['Tanggal', 'Nama Media', 'Judul', 'Link'])

    return df

# %%
df_infolampung = get_search_results_infolampung(keyword, max_pages, timeout)
df_infolampung
# Out:
#       Tanggal    Nama Media  \
# 0  2025-07-10  Info Lampung
# 1  2025-05-13  Info Lampung
# 2  2025-06-19  Info Lampung
#
#                                                Judul  \
# 0  Walikota Eva Dwiana Siap Dukung dan Beri Bantu...
# 1  Bunda Eva Dampingi Kunjungan Kerja Mensos Saif...
# 2  Mantap! Pemkab Lamsel Naikkan Anggaran Infrast...
#
#                                                 Link
# 0  https://www.infolampung.id/2025/07/10/walikota...
# 1  https://www.infolampung.id/2025/05/13/bunda-ev...
# 2  https://www.infolampung.id/2025/06/19/mantap-p...

# %% [markdown]
# # LAMPUNG DALAM BERITA

# %%
def get_search_results_lampungdalamberita(keyword, max_pages, timeout):
    page = 1
    # List penampung data
    tanggal_list = []
    nama_media_list = []
    judul_list = []
    link_list = []

    while page <= max_pages:
        url = f"https://lampungdalamberita.com/page/{page}/?s={keyword}"
        response = requests.get(url, timeout)

        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            articles = soup.find_all("article", class_="hentry")

            for art in articles:
                # Judul & link
                title_tag = art.find("h2", class_="post-title").find("a")
                title = title_tag.get_text(strip=True)
                link = title_tag["href"]

                # Tanggal
                date_tag = art.find("span", class_="updated")
                if date_tag:
                    raw_date = date_tag.get_text(strip=True)  # contoh: "Sep 18, 2023"
                    date_obj = datetime.strptime(raw_date, "%b %d, %Y")
                    date_str = date_obj.strftime("%Y-%m-%d")
                else:
                    date_str = None
                
                nama_media = "Lampung Dalam Berita"
                # Append ke list
                tanggal_list.append(date_str)
                nama_media_list.append(nama_media)
                judul_list.append(title)
                link_list.append(link)
                        
            # Deteksi pagination
            has_pagination = soup.find("div", class_="archive-pagination") is not None

            if has_pagination:
                page=page+1
            else:
                break
        else:
            break
    
    # Buat DataFrame
    data = {
        'Tanggal': tanggal_list,
        'Nama Media': nama_media_list,
        'Judul': judul_list,
        'Link': link_list
    }
    df = pd.DataFrame(data, columns=['Tanggal', 'Nama Media', 'Judul', 'Link'])

    return df

# %%
df_lampungdalamberita = get_search_results_lampungdalamberita(keyword, max_pages, timeout)
df_lampungdalamberita
# Out:
# 1
# https://lampungdalamberita.com/page/1/?s=Sekolah+Rakyat
# 2
# https://lampungdalamberita.com/page/2/?s=Sekolah+Rakyat
# 3
# https://lampungdalamberita.com/page/3/?s=Sekolah+Rakyat
# 4
# https://lampungdalamberita.com/page/4/?s=Sekolah+Rakyat
# 5
# https://lampungdalamberita.com/page/5/?s=Sekolah+Rakyat
#        Tanggal            Nama Media  \
# 0   2024-02-12  Lampung Dalam Berita
# 1   2025-06-26  Lampung Dalam Berita
# 2   2025-06-26  Lampung Dalam Berita
# 3   2025-07-31  Lampung Dalam Berita
# 4   2025-02-25  Lampung Dalam Berita
# 5   2025-02-25  Lampung Dalam Berita
# 6   2023-05-25  Lampung Dalam Berita
# 7   2023-02-10  Lampung Dalam Berita
# 8   2023-02-09  Lampung Dalam Berita
# 9   2023-02-07  Lampung Dalam Berita
# 10  2023-01-24  Lampung Dalam Berita
# 11  2022-11-01  Lampung Dalam Berita
# 12  2022-10-10  Lampung Dalam Berita
# 13  2022-08-05  Lampung Dalam Berita
# 14  2022-08-05  Lampung Dalam Berita
# 15  2022-07-19  Lampung Dalam Berita
# 16  2021-10-11  Lampung Dalam Berita
# 17  2021-09-13  Lampung Dalam Berita
# 18  2021-04-12  Lampung Dalam Berita
#
#                                                 Judul  \
# 0   CASN P3K 2023 Curhat di Gedung Rakyat, Mingrum...
# 1   Pemerintah Kabupaten Lampung Selatan tengah me...
# 2   Pemerintah Kabupaten Lampung Selatan tengah me...
# 3   Upacara Pembukaan Pendidikan Pembentukan Binta...
# 4   DPRD Lampung Apresiasi Gebernur Lampung, Sebut...
# 5   DPRD Provinsi Lampung Dukung Instruksi Gubernu...
# 6   OJK LAMPUNG TERUS PERKUAT PERAN INDUSTRI JASA ...
# 7   DKP Provinsi Lampung Bersama Alumni Fakultas K...
# 8   Bupati Lampung Utara minta Polda Lampung, beri...
# 9   Mikdar Ilyas Prihatin Terhadap Marak Tawuran d...
# 10  Kunjungan Kerja di Lampung Barat, Gubernur Ari...
# 11  Masyarakat Lima Kampung Kecamatan Pubian Sampa...
# 12  Pemilihan Ketua OSIS SMK AL Hikmah Kalirejo Di...
# 13  Mingrum Gumay : Penerapan Nilai-Nilai Pancasil...
# 14  Astri Mela Agustin : IPWK Sangat Penting Untuk...
# 15  Mingrum Gumay SH., MH Menggelar Sosialisasi Id...
# 16  Bupati Respon Keluhan Warga Soal Jembatan Dan ...
# 17  Dprd Tanggamus Gelar Paripurna Bahas Anggaran ...
# 18  Gubernur Arinal Buka Musrenbang Provinsi Lampu...
#
#                                                  Link
# 0   https://lampungdalamberita.com/2024/02/12/casn...
# 1   https://lampungdalamberita.com/2025/06/26/peme...
# 2   https://lampungdalamberita.com/2025/06/26/peme...
# 3   https://lampungdalamberita.com/2025/07/31/upac...
# 4   https://lampungdalamberita.com/2025/02/25/dprd...
# 5   https://lampungdalamberita.com/2025/02/25/dprd...
# 6   https://lampungdalamberita.com/2023/05/25/ojk-...
# 7   https://lampungdalamberita.com/2023/02/10/dkp-...
# 8   https://lampungdalamberita.com/2023/02/09/bupa...
# 9   https://lampungdalamberita.com/2023/02/07/mikd...
# 10  https://lampungdalamberita.com/2023/01/24/kunj...
# 11  https://lampungdalamberita.com/2022/11/01/masy...
# 12  https://lampungdalamberita.com/2022/10/10/pemi...
# 13  https://lampungdalamberita.com/2022/08/05/ming...
# 14  https://lampungdalamberita.com/2022/08/05/astr...
# 15  https://lampungdalamberita.com/2022/07/19/ming...
# 16  https://lampungdalamberita.com/2021/10/11/bupa...
# 17  https://lampungdalamberita.com/2021/09/13/dprd...
# 18  https://lampungdalamberita.com/2021/04/12/gube...

# %% [markdown]
# # KATA LAMPUNG

# %%
def get_search_results_katalampung(keyword, max_pages, timeout):
    page = 0

    # List penampung data
    tanggal_list = []
    nama_media_list = []
    judul_list = []
    link_list = []
    
    bulan_map = {
    "Januari": "01", "Februari": "02", "Maret": "03", "April": "04",
    "Mei": "05", "Juni": "06", "Juli": "07", "Agustus": "08",
    "September": "09", "Oktober": "10", "November": "11", "Desember": "12"
    }

    maxp = max_pages*20
    while page <= maxp:
        url = f"https://www.katalampung.com/search?q={keyword}&max-results=20&start={page}&by-date=false"
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36"
        }
        response = requests.get(url, headers=headers, timeout=timeout)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            posts = soup.find_all("div", class_="post-outer")
            for post in posts:
                title_tag = post.find("h2", class_="post-title").a
                title = title_tag.get_text(strip=True)
                link = title_tag["href"]

                # Tanggal
                date_tag = post.find("abbr", class_="published")
                if date_tag:
                    raw_date = date_tag.get_text(strip=True)
                    # Pecah tanggal format "Agustus 06, 2022"
                    parts = raw_date.replace(",", "").split()
                    bulan = bulan_map.get(parts[0], "01")
                    day = parts[1].zfill(2)
                    year = parts[2]
                    tanggal_fix = f"{year}-{bulan}-{day}"
                else:
                    tanggal_fix = None
                
                nama_media = "Kata Lampung"
                # Append ke list
                tanggal_list.append(tanggal_fix)
                nama_media_list.append(nama_media)
                judul_list.append(title)
                link_list.append(link)
                        
            # Deteksi pagination
            has_pagination = soup.find("div", class_="blog-pager") is not None
            if has_pagination:
                page=page+20
            else:
                break
        else:
            break
    # Buat DataFrame
    data = {
        'Tanggal': tanggal_list,
        'Nama Media': nama_media_list,
        'Judul': judul_list,
        'Link': link_list
    }
    df = pd.DataFrame(data, columns=['Tanggal', 'Nama Media', 'Judul', 'Link'])

    return df

# %%
df_katalampung = get_search_results_katalampung(keyword, max_pages, timeout)
df_katalampung
# Out:
#        Tanggal    Nama Media  \
# 0   2025-04-26  Kata Lampung
# 1   2025-04-23  Kata Lampung
# 2   2020-03-20  Kata Lampung
# 3   2021-03-16  Kata Lampung
# 4   2021-11-23  Kata Lampung
# 5   2020-02-11  Kata Lampung
# 6   2017-10-23  Kata Lampung
# 7   2020-06-09  Kata Lampung
# 8   2020-03-13  Kata Lampung
# 9   2020-06-17  Kata Lampung
# 10  2020-06-15  Kata Lampung
# 11  2017-12-14  Kata Lampung
# 12  2021-03-17  Kata Lampung
# 13  2018-05-03  Kata Lampung
# 14  2018-03-25  Kata Lampung
# 15  2021-02-15  Kata Lampung
# 16  2018-01-24  Kata Lampung
# 17  2017-11-17  Kata Lampung
# 18  2025-06-17  Kata Lampung
# 19  2022-10-25  Kata Lampung
# 20  2020-09-14  Kata Lampung
# 21  2018-05-03  Kata Lampung
# 22  2018-01-04  Kata Lampung
# 23  2017-10-27  Kata Lampung
# 24  2020-01-22  Kata Lampung
# 25  2018-04-23  Kata Lampung
# 26  2018-05-11  Kata Lampung
# 27  2017-11-21  Kata Lampung
# 28  2018-09-17  Kata Lampung
# 29  2020-03-15  Kata Lampung
# 30  2019-01-01  Kata Lampung
# 31  2021-04-07  Kata Lampung
# 32  2020-09-02  Kata Lampung
# 33  2019-04-09  Kata Lampung
# 34  2020-03-16  Kata Lampung
# 35  2020-07-16  Kata Lampung
# 36  2018-02-07  Kata Lampung
# 37  2020-09-06  Kata Lampung
# 38  2020-02-29  Kata Lampung
# 39  2018-05-15  Kata Lampung
# 40  2017-12-25  Kata Lampung
# 41  2020-03-12  Kata Lampung
# 42  2019-10-28  Kata Lampung
#
#                                                 Judul  \
# 0   Pemprov Lampung Siapkan Kota Baru sebagai Loka...
# 1   Gubernur Mirza Dorong Pendirian Sekolah Rakyat...
# 2    Pelaksanaan MTQ Tingkat Provinsi Lampung Diundur
# 3   PKS Lampung Soroti Keluhan Masyarakat Soal Mah...
# 4   Pentingnya Penerapan Manajemen Waktu pada Anak...
# 5   Gubernur Lampung Buka Uji Kompetensi Kepala Se...
# 6   SMI: Indonesia Semakin Bergantung Korporasi da...
# 7   Anggota Komsi V DPRD Lampung: Penerapan New No...
# 8   Senam Lampung Berjaya Makin Populer, Riana Ari...
# 9   Anggota Komisi V DPRD Lampung Tinjau Calon Pem...
# 10  DPRD Lampung Sarankan Sekolah Maksimalkan Pend...
# 11  Yustin Ridho Ficardo Siap Perjuangkan Hak Guru...
# 12  Deni Ribowo Tanggapi Wacana Dimulainya Sekolah...
# 13  Mendiknas Ingatkan Hakdiknas Sebagai Momentum ...
# 14  Mahasiswa Magister Pendidikan IPS Unila Gelar ...
# 15  Anggota DPRD Lampung Turun ke Dapil Cegah Penu...
# 16  Warga Suoh Lampung Barat Antusias Sambut Guber...
# 17  Pemprov Lampung Ajak REI Percepat Penyediaan R...
# 18  Pemprov Lampung Ikuti Arahan Kemendagri Terkai...
# 19  Riana Sari Arinal melantik Winarni Nanang Erma...
# 20  Sekdaprov Lampung Menjadi Penguji Kegiatan Sek...
# 21  Selain Program Strategis Ridho Dinilai Menyent...
# 22  Megawati Umumkan Rekomendasi PDIP ke Herman HN...
# 23  Peringati Sumpah Pemuda, Kandang Buku Gelar Pa...
# 24  Paparkan Visi Misi, TEC Siap Berikan Pengabdia...
# 25  Di Margo Rejo Lamsel, Yustin Ficardo Kampanyek...
# 26  P2K2 PKH Diharapkan Mampu Menyukseskan Pendidi...
# 27  Siswa SMA Islam Kebumen Tanggamus Pentaskan Ta...
# 28   STSQABM Gelar Stadium General Pencegahan Korupsi
# 29  Lampung Craft 2020 Ajang Promosi dan Tingkatka...
# 30  Gubernur M.Ridho Ficardo Paparkan Capaian Pemb...
# 31  Sosialisasi 4 Pilar Kebangsaan, Dwita Ria Tega...
# 32  Gelar Reses, Warga Keluhkan Dari Dagangan yang...
# 33  Mbak Tutut: Jadikan Indonesia Bangsa yang Diho...
# 34  Tangani Corona, Gubernur Lampung Arinal Djunai...
# 35  Riana Sari Arinal Lantik Pengurus Yayasan Jant...
# 36  Bupati Lampung Timur Buka Sarasehan Kabupaten ...
# 37  Yose Rizal Serap Aspirasi Masyarakat Lampung U...
# 38  Gubernur Arinal Hadiri Acara Pujawali Pura Ker...
# 39  Warga: Yang Lain Baru Janji, Ridho-Bachtiar Su...
# 40  Inacor Himbau Anies Harus Sapu Bersih Birokrat...
# 41  Sekda Provinsi Lampung : Musrenbang Kota Banda...
# 42  Tony Eka Candra Paparkan Visi Misi Balon Bupat...
#
#                                                  Link
# 0   https://www.katalampung.com/2025/04/pemprov-la...
# 1   https://www.katalampung.com/2025/04/gubernur-m...
# 2   https://www.katalampung.com/2020/03/pelaksanaa...
# 3   https://www.katalampung.com/2021/04/pks-lampun...
# 4   https://www.katalampung.com/2021/11/pentingnya...
# 5   https://www.katalampung.com/2020/02/gubernur-l...
# 6   https://www.katalampung.com/2017/10/smi-indone...
# 7   https://www.katalampung.com/2020/06/anggota-ko...
# 8   https://www.katalampung.com/2020/03/senam-lamp...
# 9   https://www.katalampung.com/2020/06/anggota-ko...
# 10  https://www.katalampung.com/2020/06/dprd-lampu...
# 11  https://www.katalampung.com/2017/12/yustin-rid...
# 12  https://www.katalampung.com/2021/04/deni-ribow...
# 13  https://www.katalampung.com/2018/05/mendiknas-...
# 14  https://www.katalampung.com/2018/03/mahasiswa-...
# 15  https://www.katalampung.com/2021/02/anggota-dp...
# 16  https://www.katalampung.com/2018/01/warga-suoh...
# 17  https://www.katalampung.com/2017/11/pemprov-la...
# 18  https://www.katalampung.com/2025/06/pemprov-la...
# 19  https://www.katalampung.com/2022/10/riana-sari...
# 20  https://www.katalampung.com/2020/09/sekdaprov-...
# 21  https://www.katalampung.com/2018/05/selain-pro...
# 22  https://www.katalampung.com/2018/01/megawati-u...
# 23  https://www.katalampung.com/2017/10/peringati-...
# 24  https://www.katalampung.com/2020/01/paparkan-v...
# 25  https://www.katalampung.com/2018/04/di-margo-r...
# 26  https://www.katalampung.com/2018/05/p2k2-pkh-d...
# 27  https://www.katalampung.com/2017/11/siswa-sma-...
# 28  https://www.katalampung.com/2018/09/stsqabm-ge...
# 29  https://www.katalampung.com/2020/03/lampung-cr...
# 30  https://www.katalampung.com/2019/01/gubernur-m...
# 31  https://www.katalampung.com/2021/04/sosialisas...
# 32  https://www.katalampung.com/2020/09/gelar-rese...
# 33  https://www.katalampung.com/2019/04/mbak-tutut...
# 34  https://www.katalampung.com/2020/03/tangani-co...
# 35  https://www.katalampung.com/2020/07/riana-sari...
# 36  https://www.katalampung.com/2018/02/bupati-lam...
# 37  https://www.katalampung.com/2020/09/yose-rizal...
# 38  https://www.katalampung.com/2020/02/gubernur-a...
# 39  https://www.katalampung.com/2018/05/warga-yang...
# 40  https://www.katalampung.com/2017/12/inacor-him...
# 41  https://www.katalampung.com/2020/03/sekda-prov...
# 42  https://www.katalampung.com/2019/10/tony-eka-c...

# %% [markdown]
# # FINALISASI

# %%
df_list = [df_antaranews, df_viva, df_lampungpost, df_sinarlampung, df_detiksumbagsel, df_harianlampung, df_harianfajarlampung, df_serambilampung, df_gemamedia, df_infolampung, df_lampungdalamberita, df_katalampung]
df_nonempty = [df for df in df_list if len(df) > 0]

if df_nonempty:
    df_final = pd.concat(df_nonempty, ignore_index=True)
else:
    df_final = pd.DataFrame(columns=["Tanggal", "Nama Media", "Judul", "Link"])

df_final = df_final.drop_duplicates(subset=['Link'])
df_final["Tanggal"] = pd.to_datetime(df_final["Tanggal"], errors="coerce")
df_final = df_final.sort_values(by="Tanggal", ascending=False)
df_final = df_final.reset_index(drop=True)
df_final
# Out:
#        Tanggal      Nama Media  \
# 0   2025-08-13  detikSumbagsel
# 1   2025-08-13    Lampung Post
# 2   2025-08-13  detikSumbagsel
# 3   2025-08-13    Lampung Post
# 4   2025-08-13    Lampung Post
# ..         ...             ...
# 416 2017-12-14    Kata Lampung
# 417 2017-11-21    Kata Lampung
# 418 2017-11-17    Kata Lampung
# 419 2017-10-27    Kata Lampung
# 420 2017-10-23    Kata Lampung
#
#                                                  Judul  \
# 0    Curi Kotak Amal di 11 TKP untuk Beli Sabu, Rem...
# 1    MBG di SMAN 1 Bandar Lampung Disambut Antusias...
# 2    Bea Cukai Gagal Penyelundupan 10 Ribu Koli Bar...
# 3       Polres Lampung Timur Tangkap Tiga Pelaku Curas
# 4    Klub Asal Italia Como Resmi Datangkan Alvaro M...
# ..                                                 ...
# 416  Yustin Ridho Ficardo Siap Perjuangkan Hak Guru...
# 417  Siswa SMA Islam Kebumen Tanggamus Pentaskan Ta...
# 418  Pemprov Lampung Ajak REI Percepat Penyediaan R...
# 419  Peringati Sumpah Pemuda, Kandang Buku Gelar Pa...
# 420  SMI: Indonesia Semakin Bergantung Korporasi da...
#
#                                                   Link
# 0    https://www.detik.com/sumbagsel/hukum-dan-krim...
# 1    https://lampost.co/humaniora/mbg-di-sman-1-ban...
# 2    https://www.detik.com/sumbagsel/hukum-dan-krim...
# 3    https://lampost.co/kriminal/polres-lampung-tim...
# 4    https://lampost.co/olahraga/klub-asal-italia-c...
# ..                                                 ...
# 416  https://www.katalampung.com/2017/12/yustin-rid...
# 417  https://www.katalampung.com/2017/11/siswa-sma-...
# 418  https://www.katalampung.com/2017/11/pemprov-la...
# 419  https://www.katalampung.com/2017/10/peringati-...
# 420  https://www.katalampung.com/2017/10/smi-indone...
#
# [421 rows x 4 columns]

# %%
namafile = f"data_berita_Lampung_{keyword}.csv"
df_final.to_csv(namafile, index=False)
print(f"Data berhasil digabungkan dan disimpan sebagai {namafile}")
# Out:
# Data berhasil digabungkan dan disimpan sebagai data_berita_Lampung_Sekolah+Rakyat.csv
